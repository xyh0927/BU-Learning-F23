# %%
# !spark-submit final_project.py airline-safety.csv
# Out:
# Figure(1000x600)
# Figure(1000x600)
#
# Period: 85_99
#
# Model: LogisticRegression
# Accuracy: 0.9333333333333333
# F1 Score: 0.9354497354497354
# Precision: 0.9466666666666667
# Recall: 0.9333333333333333
# AUC: 0.9090909090909091
# TP: 10, TN: 4, FP: 0, FN: 1
#
# Baseline Model (Predict all as 1)
# Accuracy: 0.7333333333333333
# Figure(500x500)
# Figure(640x480)
#
# Model: DecisionTreeClassifier
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# AUC: 1.0
# TP: 11, TN: 4, FP: 0, FN: 0
#
# Model: RandomForestClassifier
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# AUC: 1.0
# TP: 11, TN: 4, FP: 0, FN: 0
#
# Regression Model: Linear Regression
# R-Squared (R2) on test data = 1.0
# Root Mean Squared Error (RMSE) on test data = 2.8691622885478434e-15
#
# Period: 00_14
#
# Model: LogisticRegression
# Accuracy: 1.0
# F1 Score: 1.0
# Precision: 1.0
# Recall: 1.0
# AUC: 1.0
# TP: 5, TN: 10, FP: 0, FN: 0
#
# Baseline Model (Predict all as 0)
# ...
