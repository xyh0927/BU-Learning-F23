# %%
# !spark-submit --driver-memory 16g --conf "spark.driver.maxResultSize=16g"  t2.py 20-news-same-line.txt finaltext
# Out:
# 0
# 1
# #
# # There is insufficient memory for the Java Runtime Environment to continue.
# # Native memory allocation (mmap) failed to map 12280922112 bytes for G1 virtual space
# # An error report file with more information is saved as:
# # g:\BU_STUDY\METCS777O1\hw6\hs_err_pid17380.log
# 23/10/18 01:09:23 INFO SparkContext: Running Spark version 3.5.0
# 23/10/18 01:09:23 INFO SparkContext: OS info Windows 11, 10.0, amd64
# 23/10/18 01:09:23 INFO SparkContext: Java version 17.0.6
# 23/10/18 01:09:24 INFO ResourceUtils: ==============================================================
# 23/10/18 01:09:24 INFO ResourceUtils: No custom resources configured for spark.driver.
# 23/10/18 01:09:24 INFO ResourceUtils: ==============================================================
# 23/10/18 01:09:24 INFO SparkContext: Submitted application: A6
# ...
