# %%
# !spark-submit lastname_name_Assignment_3_task_1.py taxi-data-sorted-small.csv.bz2 out1 out2 out3
# Out:
# Task 1
# (m:  2.701426407735538 , b:  3.9501934248399837 )
# Execution Time for Task 1: 14.96433138847351 seconds
# 23/09/26 17:29:40 INFO SparkContext: Running Spark version 3.5.0
# 23/09/26 17:29:40 INFO SparkContext: OS info Windows 11, 10.0, amd64
# 23/09/26 17:29:40 INFO SparkContext: Java version 17.0.6
# 23/09/26 17:29:40 INFO ResourceUtils: ==============================================================
# 23/09/26 17:29:40 INFO ResourceUtils: No custom resources configured for spark.driver.
# 23/09/26 17:29:40 INFO ResourceUtils: ==============================================================
# 23/09/26 17:29:40 INFO SparkContext: Submitted application: Assignment-3
# ...
